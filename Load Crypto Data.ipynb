# %%
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'

# %%
import matplotlib.pyplot as plt
import warnings
import seaborn as sns

plt.style.use('seaborn')
sns.set_palette('cubehelix')
# plt.style.use('seaborn-colorblind') #alternative
plt.rcParams['figure.figsize'] = [8, 4.5]
plt.rcParams['figure.dpi'] = 300
warnings.simplefilter(action='ignore', category=FutureWarning)

# %%
import yfinance as yf
import numpy as np
import pandas as pd
import pyfolio as pf
# Out:
# c:\programming languages\python\python395\lib\site-packages\pyfolio\pos.py:26: UserWarning: Module "zipline.assets" not found; mutltipliers will not be applied to position notionals.
#   warnings.warn(

# %%
RISKY_ASSETS = ['BTC-USD', 'ETH-USD', 'LTC-USD', 'BCH-USD', 'EOS-USD', 'XRP-USD','ETC-USD', 'TRX-USD', 'BNB-USD', 
           'MTL-USD', 'NEO-USD', 'XLM-USD','ADA-USD', 'QTUM-USD', 'ZEC-USD', 'LINK-USD', 'DOGE-USD','OMG-USD', 
           'XMR-USD', 'XTZ-USD', 'SNT-USD', 'WAVES-USD','NULS-USD', 'REP-USD', 'STEEM-USD', 'ARK-USD', 
           'BTG-USD','XEM-USD', 'WTC-USD', 'ICX-USD', 'GAS-USD', 'PIVX-USD', 'HC-USD','GXC-USD', 'AE-USD', 
           'MIOTA-USD', 'EMC2-USD', 'NAS-USD', 'RLC-USD','PAY-USD', 'PPT-USD', 'MONA-USD', 'FUN-USD', 
           'ADK-USD', 'MLN-USD','LBC-USD', 'SKY-USD', 'NXT-USD', 'ETP-USD', 'YOYOW-USD']
START_DATE = '2020-01-01'
# END_DATE = '2020-12-31'
END_DATE = '2021-01-01'

n_assets = len(RISKY_ASSETS)

# %%
prices_df = yf.download(RISKY_ASSETS, start=START_DATE, 
                        end=END_DATE, adjusted=True)
print(f'Downloaded {prices_df.shape[0]} rows of data.')
# Out:
# [*********************100%***********************]  50 of 50 completed
# Downloaded 363 rows of data.

# %%
prices_df['Close']
# Out:
#              ADA-USD   ADK-USD    AE-USD   ARK-USD     BCH-USD    BNB-USD  \
# Date
# 2019-12-31  0.032845  1.356028  0.129415  0.144320  204.623169  13.727642
# 2020-01-01  0.033458  1.277238  0.129967  0.140783  204.397537  13.689083
# 2020-01-02  0.032751  1.156526  0.126175  0.139641  195.698563  13.027011
# 2020-01-03  0.034180  1.120977  0.129755  0.146057  222.412979  13.660452
# 2020-01-04  0.034595  1.211817  0.132481  0.148363  226.018692  13.891512
# ...              ...       ...       ...       ...         ...        ...
# 2020-12-27  0.154422  0.250822  0.092944  0.395159  338.179962  33.511848
# 2020-12-28  0.176735  0.254929  0.092475  0.385009  362.092041  35.844559
# 2020-12-29  0.192164  0.254605  0.088812  0.374367  353.090637  38.952831
# 2020-12-30  0.184040  0.301295  0.086121  0.378767  358.808014  38.136299
# 2020-12-31  0.181397  0.290089  0.081669  0.378559  343.052643  37.376034
#
#                  BTC-USD   BTG-USD  DOGE-USD  EMC2-USD  ...   TRX-USD  \
# ...
